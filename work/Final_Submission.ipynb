# %%
import pandas as pd

# %%
CA_1= pd.read_csv("../work/CA_1.csv")

CA_1['Analysis\nDate\nTime\n(Def.)'] = CA_1['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_1['Detection\nQuantitation\nLimit\n(Def.)'] = CA_1['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_1['Date']= pd.to_datetime(CA_1['Start\nDate\n(Def.)'],errors='raise')
CA_1.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA253340       Crissy Field        BAY#202.5_SL
# 1         CA253340       Crissy Field        BAY#202.5_SL
# 2         CA253340       Crissy Field        BAY#202.5_SL
# 3         CA253340       Crissy Field        BAY#202.4_SL
# 4         CA253340       Crissy Field        BAY#202.4_SL
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0         BAY#202.5_SL        SAN FRANCISCO             2816891
# 1         BAY#202.5_SL        SAN FRANCISCO             2816890
# 2         BAY#202.5_SL        SAN FRANCISCO             2816889
# 3         BAY#202.4_SL        SAN FRANCISCO             2816888
# 4         BAY#202.4_SL        SAN FRANCISCO             2816887
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           31-Dec-22         10:00:00 AM                PST
# 1           31-Dec-22         10:00:00 AM                PST
# ...

# %%
#seperate the month, day, year -- delete year, and day. keep the month #pd.date_time()

# %%
CA_1["Result\nValue\n(Def.)"] = pd.to_numeric(CA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_1_Total = CA_1["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_1_Total))
# Out:
# Mean: 707

# %%
CA_1["Result\nValue\n(Def.)"] = pd.to_numeric(CA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_1_Dec = CA_1["Result\nValue\n(Def.)"][0:38].mean()


print("Mean:", round(calculation_CA_1_Dec))
# Out:
# Mean: 783

# %%
CA_1["Result\nValue\n(Def.)"] = pd.to_numeric(CA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_1_Nov = CA_1["Result\nValue\n(Def.)"][39:49].mean()


print("Mean:", round(calculation_CA_1_Nov))
# Out:
# Mean: 557

# %%
CA_2= pd.read_csv("../work/CA_2.csv")

CA_2['Analysis\nDate\nTime\n(Def.)'] = CA_2['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_2['Detection\nQuantitation\nLimit\n(Def.)'] = CA_2['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_2['Date']= pd.to_datetime(CA_2['Start\nDate\n(Def.)'],errors='raise')
CA_2.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA006650      Newport Beach                 29S
# 1         CA006650      Newport Beach                 29S
# 2         CA006650      Newport Beach                 29S
# 3         CA006650      Newport Beach                 27S
# 4         CA006650      Newport Beach                 27S
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0                  29S               ORANGE             2815176
# 1                  29S               ORANGE             2815175
# 2                  29S               ORANGE             2815174
# 3                  27S               ORANGE             2815173
# 4                  27S               ORANGE             2815172
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           28-Dec-22         12:00:00 AM                PST
# 1           28-Dec-22         12:00:00 AM                PST
# ...

# %%
CA_2["Result\nValue\n(Def.)"] = pd.to_numeric(CA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_2_Total = CA_2["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_2_Total))
# Out:
# Mean: 98

# %%
CA_2["Result\nValue\n(Def.)"] = pd.to_numeric(CA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_2_Dec = CA_2["Result\nValue\n(Def.)"][0:49].mean()



print("Mean:", round(calculation_CA_2_Dec))
# Out:
# Mean: 100

# %%
CA_3= pd.read_csv("../work/CA_3.csv")

CA_3['Analysis\nDate\nTime\n(Def.)'] = CA_3['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_3['Detection\nQuantitation\nLimit\n(Def.)'] = CA_3['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')


CA_3['Date']= pd.to_datetime(CA_3['Start\nDate\n(Def.)'],errors='raise')
CA_3.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA506450      San Diego Bay              EH-200
# 1         CA506450      San Diego Bay              EH-200
# 2         CA506450      San Diego Bay              EH-200
# 3         CA506450      San Diego Bay              EH-090
# 4         CA506450      San Diego Bay              EH-070
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0               EH-200            SAN DIEGO             2819182
# 1               EH-200            SAN DIEGO             2819181
# 2               EH-200            SAN DIEGO             2819180
# 3               EH-090            SAN DIEGO             2814143
# 4               EH-070            SAN DIEGO             2814098
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           27-Dec-22          9:20:00 AM                PST
# 1           27-Dec-22          9:20:00 AM                PST
# ...

# %%
CA_3["Result\nValue\n(Def.)"] = pd.to_numeric(CA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_3_Total = CA_3["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_3_Total))
# Out:
# Mean: 302

# %%
CA_3["Result\nValue\n(Def.)"] = pd.to_numeric(CA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_3_Dec = CA_3["Result\nValue\n(Def.)"][0:27].mean()



print("Mean:", round(calculation_CA_3_Dec))
# Out:
# Mean: 315

# %%
CA_3["Result\nValue\n(Def.)"] = pd.to_numeric(CA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_3_Nov = CA_3["Result\nValue\n(Def.)"][28:47].mean()



print("Mean:", round(calculation_CA_3_Nov))
# Out:
# Mean: 156

# %%
CA_3["Result\nValue\n(Def.)"] = pd.to_numeric(CA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_3_Oct = CA_3["Result\nValue\n(Def.)"][48:49].mean()



print("Mean:", round(calculation_CA_3_Oct))
# Out:
# Mean: 41

# %%
CA_4= pd.read_csv("../work/CA_4.csv")

CA_4['Analysis\nDate\nTime\n(Def.)'] = CA_4['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_4['Detection\nQuantitation\nLimit\n(Def.)'] = CA_4['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_4['Date']= pd.to_datetime(CA_4['Start\nDate\n(Def.)'],errors='raise')
CA_4.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA997086      La Jolla Cove              FM-070
# 1         CA997086      La Jolla Cove              FM-070
# 2         CA997086      La Jolla Cove              FM-070
# 3         CA997086      La Jolla Cove              FM-070
# 4         CA997086      La Jolla Cove              FM-070
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0               FM-070            SAN DIEGO             2814162
# 1               FM-070            SAN DIEGO             2814072
# 2               FM-070            SAN DIEGO             2812446
# 3               FM-070            SAN DIEGO             2811929
# 4               FM-070            SAN DIEGO             2810880
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           23-Dec-22          6:55:00 AM                PST
# 1           22-Dec-22          6:15:00 AM                PST
# ...

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Total = CA_4["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_4_Total))
# Out:
# Mean: 2669

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Dec = CA_4["Result\nValue\n(Def.)"][0:5].mean()



print("Mean:", round(calculation_CA_4_Dec))
# Out:
# Mean: 2331

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Nov = CA_4["Result\nValue\n(Def.)"][6:7].mean()



print("Mean:", round(calculation_CA_4_Nov))
# Out:
# Mean: 1216

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Oct = CA_4["Result\nValue\n(Def.)"][8:11].mean()



print("Mean:", round(calculation_CA_4_Oct))
# Out:
# Mean: 1446

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Sep = CA_4["Result\nValue\n(Def.)"][12:14].mean()



print("Mean:", round(calculation_CA_4_Sep))
# Out:
# Mean: 1676

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Aug = CA_4["Result\nValue\n(Def.)"][15:19].mean()



print("Mean:", round(calculation_CA_4_Aug))
# Out:
# Mean: 2419

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Jul = CA_4["Result\nValue\n(Def.)"][20:24].mean()



print("Mean:", round(calculation_CA_4_Jul))
# Out:
# Mean: 1808

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Jun = CA_4["Result\nValue\n(Def.)"][25:28].mean()



print("Mean:", round(calculation_CA_4_Jun))
# Out:
# Mean: 1872

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_May = CA_4["Result\nValue\n(Def.)"][29:36].mean()



print("Mean:", round(calculation_CA_4_May))
# Out:
# Mean: 1323

# %%
CA_4["Result\nValue\n(Def.)"] = pd.to_numeric(CA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_4_Apr = CA_4["Result\nValue\n(Def.)"][37:49].mean()



print("Mean:", round(calculation_CA_4_Apr))
# Out:
# Mean: 134

# %%
CA_5= pd.read_csv("../work/CA_5.csv")

CA_5['Analysis\nDate\nTime\n(Def.)'] = CA_5['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_5['Detection\nQuantitation\nLimit\n(Def.)'] = CA_5['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_5['Date']= pd.to_datetime(CA_5['Start\nDate\n(Def.)'],errors='raise')
CA_5.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA853136       Laguna Beach               WESTZ
# 1         CA853136       Laguna Beach               WESTZ
# 2         CA853136       Laguna Beach               WESTZ
# 3         CA853136       Laguna Beach             VICTRAZ
# 4         CA853136       Laguna Beach             VICTRAZ
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0                WESTZ               ORANGE             2815192
# 1                WESTZ               ORANGE             2815191
# 2                WESTZ               ORANGE             2815190
# 3              VICTRAZ               ORANGE             2814970
# 4              VICTRAZ               ORANGE             2814969
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           29-Dec-22         12:00:00 AM                PST
# 1           29-Dec-22         12:00:00 AM                PST
# ...

# %%
CA_5["Result\nValue\n(Def.)"] = pd.to_numeric(CA_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_5_Total = CA_5["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_5_Total))
# Out:
# Mean: 27

# %%
CA_5["Result\nValue\n(Def.)"] = pd.to_numeric(CA_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_5_Dec = CA_5["Result\nValue\n(Def.)"][0:49].mean()



print("Mean:", round(calculation_CA_5_Dec))
# Out:
# Mean: 26

# %%
CA_6= pd.read_csv("../work/CA_6.csv")

CA_6['Analysis\nDate\nTime\n(Def.)'] = CA_6['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_6['Detection\nQuantitation\nLimit\n(Def.)'] = CA_6['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_6['Date']= pd.to_datetime(CA_6['Start\nDate\n(Def.)'],errors='raise')
CA_6.head()
# Out:
#   Beach ID\n(Def.)                Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         CA775561  Julia Pfeiffer Burns State Beach                 PFB
# 1         CA775561  Julia Pfeiffer Burns State Beach                 PFB
# 2         CA775561  Julia Pfeiffer Burns State Beach                 PFB
# 3         CA775561  Julia Pfeiffer Burns State Beach                 PFB
# 4         CA775561  Julia Pfeiffer Burns State Beach                 PFB
#
#   Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0                  PFB             MONTEREY             2788404
# 1                  PFB             MONTEREY             2788403
# 2                  PFB             MONTEREY             2788402
# 3                  PFB             MONTEREY             2759304
# 4                  PFB             MONTEREY             2759303
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           01-Aug-22          9:40:00 AM                PST
# ...

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Total = CA_6["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_6_Total))
# Out:
# Mean: 471

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Aug = CA_6["Result\nValue\n(Def.)"][0:2].mean()



print("Mean:", round(calculation_CA_6_Aug))
# Out:
# Mean: 10

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Apr = CA_6["Result\nValue\n(Def.)"][3:5].mean()



print("Mean:", round(calculation_CA_6_Apr))
# Out:
# Mean: 15

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Mar = CA_6["Result\nValue\n(Def.)"][6:8].mean()



print("Mean:", round(calculation_CA_6_Mar))
# Out:
# Mean: 10

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Feb = CA_6["Result\nValue\n(Def.)"][9:11].mean()



print("Mean:", round(calculation_CA_6_Feb))
# Out:
# Mean: 10

# %%
CA_6["Result\nValue\n(Def.)"] = pd.to_numeric(CA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_6_Jan = CA_6["Result\nValue\n(Def.)"][12:14].mean()



print("Mean:", round(calculation_CA_6_Jan))
# Out:
# Mean: 3445

# %%
CA_7= pd.read_csv("../work/CA_7.csv")

CA_7['Analysis\nDate\nTime\n(Def.)'] = CA_7['Analysis\nDate\nTime\n(Def.)'].str.replace('-','')
CA_7['Detection\nQuantitation\nLimit\n(Def.)'] = CA_7['Detection\nQuantitation\nLimit\n(Def.)'].str.replace('-','')

CA_7['Date']= pd.to_datetime(CA_7['Start\nDate\n(Def.)'],errors='raise')
CA_7.head()
# Out:
#   Beach ID\n(Def.)      Beach Name\n(Def.)  Station\nID\n(Def.)  \
# 0         CA011231  Thornhill Broome Beach                46000
# 1         CA011231  Thornhill Broome Beach                46000
# 2         CA011231  Thornhill Broome Beach                46000
# 3         CA011231  Thornhill Broome Beach                46000
# 4         CA011231  Thornhill Broome Beach                46000
#
#    Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0                 46000              VENTURA             2815386
# 1                 46000              VENTURA             2815385
# 2                 46000              VENTURA             2815384
# 3                 46000              VENTURA             2798209
# 4                 46000              VENTURA             2798208
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           25-Oct-22         12:13:00 PM                PST
# 1           25-Oct-22         12:13:00 PM                PST
# ...

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Total = CA_7["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_CA_7_Total))
# Out:
# Mean: 11

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Oct = CA_7["Result\nValue\n(Def.)"][0:8].mean()



print("Mean:", round(calculation_CA_7_Oct))
# Out:
# Mean: 11

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Sep = CA_7["Result\nValue\n(Def.)"][9:17].mean()



print("Mean:", round(calculation_CA_7_Sep))
# Out:
# Mean: 10

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Aug = CA_7["Result\nValue\n(Def.)"][18:32].mean()



print("Mean:", round(calculation_CA_7_Aug))
# Out:
# Mean: 11

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Jul = CA_7["Result\nValue\n(Def.)"][33:41].mean()



print("Mean:", round(calculation_CA_7_Jul))
# Out:
# Mean: 10

# %%
CA_7["Result\nValue\n(Def.)"] = pd.to_numeric(CA_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_CA_7_Jun = CA_7["Result\nValue\n(Def.)"][42:49].mean()



print("Mean:", round(calculation_CA_7_Jun))
# Out:
# Mean: 10

# %%
OR_1= pd.read_csv("../work/OR_1.csv")

OR_1['Sample Collection\nMethod Identifier\n(Def.)'] = OR_1['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_1['Sample Collection\nMethod Name\n(Def.)'] = OR_1['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_1['Field Gear\n(Def.)'] = OR_1['Field Gear\n(Def.)'].str.replace('-','')

OR_1['Date']= pd.to_datetime(OR_1['Start\nDate\n(Def.)'],errors='raise')
OR_1.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR244981   BASTENDORF BEACH         31562-ORDEQ
# 1         OR244981   BASTENDORF BEACH         31562-ORDEQ
# 2         OR244981   BASTENDORF BEACH         31562-ORDEQ
# 3         OR244981   BASTENDORF BEACH         31561-ORDEQ
# 4         OR244981   BASTENDORF BEACH         31561-ORDEQ
#
#                                Station Name\n(Def.) County\nName\n(Def.)  \
# 0              Bastendorff Beach 250m S of Minor Cr                 COOS
# 1              Bastendorff Beach 250m S of Minor Cr                 COOS
# 2              Bastendorff Beach 250m S of Minor Cr                 COOS
# 3  Miner Creek 200m upstream from Bastendorff Beach                 COOS
# 4  Miner Creek 200m upstream from Bastendorff Beach                 COOS
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0  31562-ORDEQ:202209201053:FM           20-Sep-22         10:53:00 AM
# ...

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_Total = OR_1["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_1_Total))
# Out:
# Mean: 92

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_Sep = OR_1["Result\nValue\n(Def.)"][0:7].mean()



print("Mean:", round(calculation_OR_1_Sep))
# Out:
# Mean: 72

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_Aug = OR_1["Result\nValue\n(Def.)"][8:21].mean()



print("Mean:", round(calculation_OR_1_Aug))
# Out:
# Mean: 160

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_Jul = OR_1["Result\nValue\n(Def.)"][22:28].mean()



print("Mean:", round(calculation_OR_1_Jul))
# Out:
# Mean: 103

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_Jun = OR_1["Result\nValue\n(Def.)"][29:42].mean()



print("Mean:", round(calculation_OR_1_Jun))
# Out:
# Mean: 61

# %%
OR_1["Result\nValue\n(Def.)"] = pd.to_numeric(OR_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_1_May = OR_1["Result\nValue\n(Def.)"][43:49].mean()


print("Mean:", round(calculation_OR_1_May))
# Out:
# Mean: 61

# %%
OR_2= pd.read_csv("../work/OR_2.csv")

OR_2['Sample Collection\nMethod Identifier\n(Def.)'] = OR_2['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_2['Sample Collection\nMethod Name\n(Def.)'] = OR_2['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_2['Field Gear\n(Def.)'] = OR_2['Field Gear\n(Def.)'].str.replace('-','')

OR_2['Date']= pd.to_datetime(OR_2['Start\nDate\n(Def.)'],errors='raise')
OR_2.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR298050       HECETA BEACH         36227-ORDEQ
# 1         OR298050       HECETA BEACH         36227-ORDEQ
# 2         OR298050       HECETA BEACH         36227-ORDEQ
# 3         OR298050       HECETA BEACH         36227-ORDEQ
# 4         OR298050       HECETA BEACH         36226-ORDEQ
#
#                                 Station Name\n(Def.) County\nName\n(Def.)  \
# 0          Heceta Beach at the south end pipe runoff                 LANE
# 1          Heceta Beach at the south end pipe runoff                 LANE
# 2          Heceta Beach at the south end pipe runoff                 LANE
# 3          Heceta Beach at the south end pipe runoff                 LANE
# 4  Heceta Beach at the mouth of the south runoff ...                 LANE
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0  36227-ORDEQ:202209191528:FM           19-Sep-22          3:28:00 PM
# ...

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_Total = OR_2["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_2_Total))
# Out:
# Mean: 49

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_Sep= OR_2["Result\nValue\n(Def.)"][0:7].mean()



print("Mean:", round(calculation_OR_2_Sep))
# Out:
# Mean: 44

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_Aug = OR_2["Result\nValue\n(Def.)"][8:21].mean()



print("Mean:", round(calculation_OR_2_Aug))
# Out:
# Mean: 52

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_Jul = OR_2["Result\nValue\n(Def.)"][22:28].mean()



print("Mean:", round(calculation_OR_2_Jul))
# Out:
# Mean: 93

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_Jun = OR_2["Result\nValue\n(Def.)"][29:42].mean()



print("Mean:", round(calculation_OR_2_Jun))
# Out:
# Mean: 40

# %%
OR_2["Result\nValue\n(Def.)"] = pd.to_numeric(OR_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_2_May = OR_2["Result\nValue\n(Def.)"][43:49].mean()



print("Mean:", round(calculation_OR_2_May))
# Out:
# Mean: 40

# %%
OR_3= pd.read_csv("../work/OR_3.csv")

OR_3['Sample Collection\nMethod Identifier\n(Def.)'] = OR_3['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_3['Sample Collection\nMethod Name\n(Def.)'] = OR_3['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_3['Field Gear\n(Def.)'] = OR_3['Field Gear\n(Def.)'].str.replace('-','')

OR_3['Date']= pd.to_datetime(OR_3['Start\nDate\n(Def.)'],errors='raise')
OR_3.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR277842       CANNON BEACH         34608-ORDEQ
# 1         OR277842       CANNON BEACH         34608-ORDEQ
# 2         OR277842       CANNON BEACH         34608-ORDEQ
# 3         OR277842       CANNON BEACH         34608-ORDEQ
# 4         OR277842       CANNON BEACH         34608-ORDEQ
#
#                                 Station Name\n(Def.) County\nName\n(Def.)  \
# 0  Ecola Court pipe at Gower Street discharge to ...              CLATSOP
# 1  Ecola Court pipe at Gower Street discharge to ...              CLATSOP
# 2  Ecola Court pipe at Gower Street discharge to ...              CLATSOP
# 3  Ecola Court pipe at Gower Street discharge to ...              CLATSOP
# 4  Ecola Court pipe at Gower Street discharge to ...              CLATSOP
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0  34608-ORDEQ:202211211323:FM           21-Nov-22          1:23:00 PM
# ...

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Total = OR_3["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_3_Total))
# Out:
# Mean: 74

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Nov = OR_3["Result\nValue\n(Def.)"][0:7].mean()



print("Mean:", round(calculation_OR_3_Nov))
# Out:
# Mean: 117

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Oct = OR_3["Result\nValue\n(Def.)"][8:23].mean()



print("Mean:", round(calculation_OR_3_Oct))
# Out:
# Mean: 103

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Sept = OR_3["Result\nValue\n(Def.)"][24:31].mean()



print("Mean:", round(calculation_OR_3_Sept))
# Out:
# Mean: 49

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Aug = OR_3["Result\nValue\n(Def.)"][24:43].mean()



print("Mean:", round(calculation_OR_3_Aug))
# Out:
# Mean: 48

# %%
OR_3["Result\nValue\n(Def.)"] = pd.to_numeric(OR_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_3_Jul = OR_3["Result\nValue\n(Def.)"][44:49].mean()



print("Mean:", round(calculation_OR_3_Jul))
# Out:
# Mean: 61

# %%
OR_4= pd.read_csv("../work/OR_4.csv")

OR_4['Sample Collection\nMethod Identifier\n(Def.)'] = OR_4['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_4['Sample Collection\nMethod Name\n(Def.)'] = OR_4['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_4['Field Gear\n(Def.)'] = OR_4['Field Gear\n(Def.)'].str.replace('-','')

OR_4['Date']= pd.to_datetime(OR_4['Start\nDate\n(Def.)'],errors='raise')
OR_4.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR329442      SEASIDE BEACH         29394-ORDEQ
# 1         OR329442      SEASIDE BEACH         29394-ORDEQ
# 2         OR329442      SEASIDE BEACH         29394-ORDEQ
# 3         OR329442      SEASIDE BEACH         29393-ORDEQ
# 4         OR329442      SEASIDE BEACH         29393-ORDEQ
#
#            Station Name\n(Def.) County\nName\n(Def.)  \
# 0     Seaside Beach at U Avenue              CLATSOP
# 1     Seaside Beach at U Avenue              CLATSOP
# 2     Seaside Beach at U Avenue              CLATSOP
# 3  Seaside Beach at 12th Avenue              CLATSOP
# 4  Seaside Beach at 12th Avenue              CLATSOP
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0  29394-ORDEQ:202209261224:FM           26-Sep-22         12:24:00 PM
# 1  29394-ORDEQ:202209261224:FM           26-Sep-22         12:24:00 PM
# 2  29394-ORDEQ:202209261224:FM           26-Sep-22         12:24:00 PM
# ...

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_Total = OR_4["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_4_Total))
# Out:
# Mean: 23

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_Sep = OR_4["Result\nValue\n(Def.)"][0:11].mean()



print("Mean:", round(calculation_OR_4_Sep))
# Out:
# Mean: 22

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_Aug = OR_4["Result\nValue\n(Def.)"][12:29].mean()


print("Mean:", round(calculation_OR_4_Aug))
# Out:
# Mean: 22

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_Jul = OR_4["Result\nValue\n(Def.)"][30:40].mean()



print("Mean:", round(calculation_OR_4_Jul))
# Out:
# Mean: 22

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_Jun = OR_4["Result\nValue\n(Def.)"][41:46].mean()



print("Mean:", round(calculation_OR_4_Jun))
# Out:
# Mean: 27

# %%
OR_4["Result\nValue\n(Def.)"] = pd.to_numeric(OR_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_4_May = OR_4["Result\nValue\n(Def.)"][47:49].mean()



print("Mean:", round(calculation_OR_4_May))
# Out:
# Mean: 28

# %%
OR_5= pd.read_csv("../work/OR_5.csv")

OR_5['Sample Collection\nMethod Identifier\n(Def.)'] = OR_5['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_5['Sample Collection\nMethod Name\n(Def.)'] = OR_5['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_5['Field Gear\n(Def.)'] = OR_5['Field Gear\n(Def.)'].str.replace('-','')

OR_5['Date']= pd.to_datetime(OR_5['Start\nDate\n(Def.)'],errors='raise')
OR_5.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR953303         MILL BEACH         31687-ORDEQ
# 1         OR953303         MILL BEACH         31687-ORDEQ
# 2         OR953303         MILL BEACH         31687-ORDEQ
# 3         OR953303         MILL BEACH         30935-ORDEQ
# 4         OR953303         MILL BEACH         30935-ORDEQ
#
#                     Station Name\n(Def.) County\nName\n(Def.)  \
# 0               Mill Beach at Macklyn Cr                CURRY
# 1               Mill Beach at Macklyn Cr                CURRY
# 2               Mill Beach at Macklyn Cr                CURRY
# 3  Macklyn Creek 50m upstream from mouth                CURRY
# 4  Macklyn Creek 50m upstream from mouth                CURRY
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0  31687-ORDEQ:202209211312:FM           21-Sep-22          1:12:00 PM
# 1  31687-ORDEQ:202209211312:FM           21-Sep-22          1:12:00 PM
# ...

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_Total = OR_5["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_5_Total))
# Out:
# Mean: 53

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_Aug= OR_5["Result\nValue\n(Def.)"][8:21].mean()



print("Mean:", round(calculation_OR_5_Aug))
# Out:
# Mean: 64

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_Sep= OR_5["Result\nValue\n(Def.)"][0:7].mean()



print("Mean:", round(calculation_OR_5_Sep))
# Out:
# Mean: 61

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_Jul= OR_5["Result\nValue\n(Def.)"][22:28].mean()



print("Mean:", round(calculation_OR_5_Jul))
# Out:
# Mean: 17

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_Jun= OR_5["Result\nValue\n(Def.)"][29:42].mean()



print("Mean:", round(calculation_OR_5_Jun))
# Out:
# Mean: 60

# %%
OR_5["Result\nValue\n(Def.)"] = pd.to_numeric(OR_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_5_May= OR_5["Result\nValue\n(Def.)"][43:49].mean()



print("Mean:", round(calculation_OR_5_May))
# Out:
# Mean: 49

# %%
OR_6= pd.read_csv("../work/OR_6.csv")

OR_6['Sample Collection\nMethod Identifier\n(Def.)'] = OR_6['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_6['Sample Collection\nMethod Name\n(Def.)'] = OR_6['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_6['Field Gear\n(Def.)'] = OR_6['Field Gear\n(Def.)'].str.replace('-','')

OR_6['Date']= pd.to_datetime(OR_6['Start\nDate\n(Def.)'],errors='raise')
OR_6.head()
# Out:
#   Beach ID\n(Def.)         Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR178544  AGATE BEACH STATE WAYSIDE         34727-ORDEQ
# 1         OR178544  AGATE BEACH STATE WAYSIDE         34727-ORDEQ
# 2         OR178544  AGATE BEACH STATE WAYSIDE         34727-ORDEQ
# 3         OR178544  AGATE BEACH STATE WAYSIDE         34726-ORDEQ
# 4         OR178544  AGATE BEACH STATE WAYSIDE         34726-ORDEQ
#
#                              Station Name\n(Def.) County\nName\n(Def.)  \
# 0               Agate Beach at mouth of Big Creek              LINCOLN
# 1               Agate Beach at mouth of Big Creek              LINCOLN
# 2               Agate Beach at mouth of Big Creek              LINCOLN
# 3  Big Creek at Agate Beach Wayside at footbridge              LINCOLN
# 4  Big Creek at Agate Beach Wayside at footbridge              LINCOLN
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# ...

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_Total = OR_6["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_6_Total))
# Out:
# Mean: 36

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_Sep = OR_6["Result\nValue\n(Def.)"][0:6].mean()



print("Mean:", round(calculation_OR_6_Sep))
# Out:
# Mean: 34

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_Aug = OR_6["Result\nValue\n(Def.)"][7:20].mean()



print("Mean:", round(calculation_OR_6_Aug))
# Out:
# Mean: 38

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_Jul = OR_6["Result\nValue\n(Def.)"][21:27].mean()



print("Mean:", round(calculation_OR_6_Jul))
# Out:
# Mean: 38

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_Jun = OR_6["Result\nValue\n(Def.)"][28:46].mean()



print("Mean:", round(calculation_OR_6_Jun))
# Out:
# Mean: 32

# %%
OR_6["Result\nValue\n(Def.)"] = pd.to_numeric(OR_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_6_May = OR_6["Result\nValue\n(Def.)"][47:49].mean()



print("Mean:", round(calculation_OR_6_May))
# Out:
# Mean: 16

# %%
OR_7= pd.read_csv("../work/OR_7.csv")

OR_7['Sample Collection\nMethod Identifier\n(Def.)'] = OR_7['Sample Collection\nMethod Identifier\n(Def.)'].str.replace('-','')
OR_7['Sample Collection\nMethod Name\n(Def.)'] = OR_7['Sample Collection\nMethod Name\n(Def.)'].str.replace('-','')
OR_7['Field Gear\n(Def.)'] = OR_7['Field Gear\n(Def.)'].str.replace('-','')

OR_7['Date']= pd.to_datetime(OR_7['Start\nDate\n(Def.)'],errors='raise')
OR_7.head()
# Out:
#   Beach ID\n(Def.)            Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         OR378443  NESKOWIN BEACH STATE WAYSIDE         32133-ORDEQ
# 1         OR378443  NESKOWIN BEACH STATE WAYSIDE         32133-ORDEQ
# 2         OR378443  NESKOWIN BEACH STATE WAYSIDE         32133-ORDEQ
# 3         OR378443  NESKOWIN BEACH STATE WAYSIDE         30513-ORDEQ
# 4         OR378443  NESKOWIN BEACH STATE WAYSIDE         30513-ORDEQ
#
#                                 Station Name\n(Def.) County\nName\n(Def.)  \
# 0  Neskowin Beach at Neskowin Creek south side of...            TILLAMOOK
# 1  Neskowin Beach at Neskowin Creek south side of...            TILLAMOOK
# 2  Neskowin Beach at Neskowin Creek south side of...            TILLAMOOK
# 3  Neskowin Beach at Neskowin Creek north side of...            TILLAMOOK
# 4  Neskowin Beach at Neskowin Creek north side of...            TILLAMOOK
#
#             Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# ...

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_Total = OR_7["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_OR_7_Total))
# Out:
# Mean: 21

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_Sep = OR_7["Result\nValue\n(Def.)"][0:5].mean()



print("Mean:", round(calculation_OR_7_Sep))
# Out:
# Mean: 22

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_Aug = OR_7["Result\nValue\n(Def.)"][6:17].mean()



print("Mean:", round(calculation_OR_7_Aug))
# Out:
# Mean: 24

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_Jul = OR_7["Result\nValue\n(Def.)"][18:23].mean()



print("Mean:", round(calculation_OR_7_Jul))
# Out:
# Mean: 32

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_Jun = OR_7["Result\nValue\n(Def.)"][24:35].mean()



print("Mean:", round(calculation_OR_7_Jun))
# Out:
# Mean: 16

# %%
OR_7["Result\nValue\n(Def.)"] = pd.to_numeric(OR_7["Result\nValue\n(Def.)"], errors='coerce')

calculation_OR_7_May = OR_7["Result\nValue\n(Def.)"][36:41].mean()



print("Mean:", round(calculation_OR_7_May))
# Out:
# Mean: 17

# %%
WA_1= pd.read_csv("../work/WA_1.csv")

WA_1['Start\nTime\n(Def.)'] = WA_1['Start\nTime\n(Def.)'].str.replace('-','')
WA_1['Zone\nCode\n(Def.)'] = WA_1['Zone\nCode\n(Def.)'].str.replace('-','')

WA_1['Date']= pd.to_datetime(WA_1['Start\nDate\n(Def.)'],errors='raise')
WA_1.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA765635       Jetty Island             SNO011B
# 1         WA765635       Jetty Island             SNO011A
# 2         WA765635       Jetty Island             SNO011C
# 3         WA765635       Jetty Island             SNO011A
# 4         WA765635       Jetty Island             SNO011B
#
#     Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0  JETTY ISLAND, SNO011B            SNOHOMISH               71761
# 1  JETTY ISLAND, SNO011A            SNOHOMISH               71760
# 2  JETTY ISLAND, SNO011C            SNOHOMISH               71759
# 3  JETTY ISLAND, SNO011A            SNOHOMISH               71384
# 4  JETTY ISLAND, SNO011B            SNOHOMISH               71383
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           01-Sep-22
# 1           01-Sep-22
# 2           01-Sep-22
# 3           17-Aug-22
# 4           17-Aug-22
#
# ...

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_Total = WA_1["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_1_Total))
# Out:
# Mean: 12

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_Sep= WA_1["Result\nValue\n(Def.)"][0:2].mean()



print("Mean:", round(calculation_WA_1_Sep))
# Out:
# Mean: 15

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_Aug= WA_1["Result\nValue\n(Def.)"][3:8].mean()



print("Mean:", round(calculation_WA_1_Aug))
# Out:
# Mean: 14

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_Jul= WA_1["Result\nValue\n(Def.)"][9:14].mean()



print("Mean:", round(calculation_WA_1_Jul))
# Out:
# Mean: 10

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_Jun= WA_1["Result\nValue\n(Def.)"][15:21].mean()



print("Mean:", round(calculation_WA_1_Jun))
# Out:
# Mean: 12

# %%
WA_1["Result\nValue\n(Def.)"] = pd.to_numeric(WA_1["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_1_May= WA_1["Result\nValue\n(Def.)"][15:28].mean()



print("Mean:", round(calculation_WA_1_May))
# Out:
# Mean: 12

# %%
WA_2= pd.read_csv("../work/WA_2.csv")

WA_2['Start\nTime\n(Def.)'] = WA_2['Start\nTime\n(Def.)'].str.replace('-','')
WA_2['Zone\nCode\n(Def.)'] = WA_2['Zone\nCode\n(Def.)'].str.replace('-','')

WA_2['Date']= pd.to_datetime(WA_2['Start\nDate\n(Def.)'],errors='raise')
WA_2.head()
# Out:
#   Beach ID\n(Def.)              Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA266896  Port of Bellingham Marine Park             WHA021C
# 1         WA266896  Port of Bellingham Marine Park             WHA021E
# 2         WA266896  Port of Bellingham Marine Park             WHA021D
# 3         WA266896  Port of Bellingham Marine Park             WHA021E
# 4         WA266896  Port of Bellingham Marine Park             WHA021D
#
#                       Station Name\n(Def.) County\nName\n(Def.)  \
# 0  PORT OF BELLINGHAM MARINE PARK, WHA021C              WHATCOM
# 1  PORT OF BELLINGHAM MARINE PARK, WHA021E              WHATCOM
# 2  PORT OF BELLINGHAM MARINE PARK, WHA021D              WHATCOM
# 3  PORT OF BELLINGHAM MARINE PARK, WHA021E              WHATCOM
# 4  PORT OF BELLINGHAM MARINE PARK, WHA021D              WHATCOM
#
#    Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# 0               68681           30-Aug-22
# 1               68679           30-Aug-22
# ...

# %%
WA_2["Result\nValue\n(Def.)"] = pd.to_numeric(WA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_2_Total = WA_2["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_2_Total))
# Out:
# Mean: 70

# %%
WA_2["Result\nValue\n(Def.)"] = pd.to_numeric(WA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_2_Aug= WA_2["Result\nValue\n(Def.)"][0:19].mean()



print("Mean:", round(calculation_WA_2_Aug))
# Out:
# Mean: 41

# %%
WA_2["Result\nValue\n(Def.)"] = pd.to_numeric(WA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_2_Jul= WA_2["Result\nValue\n(Def.)"][20:34].mean()



print("Mean:", round(calculation_WA_2_Jul))
# Out:
# Mean: 63

# %%
WA_2["Result\nValue\n(Def.)"] = pd.to_numeric(WA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_2_Jun= WA_2["Result\nValue\n(Def.)"][35:46].mean()



print("Mean:", round(calculation_WA_2_Jun))
# Out:
# Mean: 16

# %%
WA_2["Result\nValue\n(Def.)"] = pd.to_numeric(WA_2["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_2_May= WA_2["Result\nValue\n(Def.)"][47:49].mean()



print("Mean:", round(calculation_WA_2_May))
# Out:
# Mean: 20

# %%
WA_3= pd.read_csv("../work/WA_3.csv")

WA_3['Start\nTime\n(Def.)'] = WA_3['Start\nTime\n(Def.)'].str.replace('-','')
WA_3['Zone\nCode\n(Def.)'] = WA_3['Zone\nCode\n(Def.)'].str.replace('-','')

WA_3['Date']= pd.to_datetime(WA_3['Start\nDate\n(Def.)'],errors='raise')
WA_3.head()
# Out:
#   Beach ID\n(Def.)  Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA192208  Arness County Park             KIT011B
# 1         WA192208  Arness County Park             KIT011C
# 2         WA192208  Arness County Park             KIT011B
# 3         WA192208  Arness County Park             KIT011A
# 4         WA192208  Arness County Park             KIT011A
#
#           Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0  ARNESS COUNTY PARK, KIT011B               KITSAP               71909
# 1  ARNESS COUNTY PARK, KIT011C               KITSAP               71908
# 2  ARNESS COUNTY PARK, KIT011B               KITSAP               71907
# 3  ARNESS COUNTY PARK, KIT011A               KITSAP               71906
# 4  ARNESS COUNTY PARK, KIT011A               KITSAP               71905
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           29-Aug-22
# 1           29-Aug-22
# 2           29-Aug-22
# 3           29-Aug-22
# ...

# %%
WA_3["Result\nValue\n(Def.)"] = pd.to_numeric(WA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_3_Total = WA_3["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_3_Total))
# Out:
# Mean: 14

# %%
WA_3["Result\nValue\n(Def.)"] = pd.to_numeric(WA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_3_Aug= WA_3["Result\nValue\n(Def.)"][0:17].mean()



print("Mean:", round(calculation_WA_3_Aug))
# Out:
# Mean: 12

# %%
WA_3["Result\nValue\n(Def.)"] = pd.to_numeric(WA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_3_Jul= WA_3["Result\nValue\n(Def.)"][18:26].mean()



print("Mean:", round(calculation_WA_3_Aug))
# Out:
# Mean: 12

# %%
WA_3["Result\nValue\n(Def.)"] = pd.to_numeric(WA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_3_Jun= WA_3["Result\nValue\n(Def.)"][27:41].mean()



print("Mean:", round(calculation_WA_3_Jun))
# Out:
# Mean: 15

# %%
WA_3["Result\nValue\n(Def.)"] = pd.to_numeric(WA_3["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_3_May= WA_3["Result\nValue\n(Def.)"][42:47].mean()



print("Mean:", round(calculation_WA_3_May))
# Out:
# Mean: 18

# %%
WA_4= pd.read_csv("../work/WA_4.csv")

WA_4['Start\nTime\n(Def.)'] = WA_4['Start\nTime\n(Def.)'].str.replace('-','')
WA_4['Zone\nCode\n(Def.)'] = WA_4['Zone\nCode\n(Def.)'].str.replace('-','')

WA_4['Date']= pd.to_datetime(WA_4['Start\nDate\n(Def.)'],errors='raise')
WA_4.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA614011    Alki Beach Park             KIN023A
# 1         WA614011    Alki Beach Park             KIN023B
# 2         WA614011    Alki Beach Park             KIN023C
# 3         WA614011    Alki Beach Park             KIN023C
# 4         WA614011    Alki Beach Park             KIN023A
#
#        Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0  ALKI BEACH PARK, KIN023A                 KING               71665
# 1  ALKI BEACH PARK, KIN023B                 KING               71664
# 2  ALKI BEACH PARK, KIN023C                 KING               71663
# 3  ALKI BEACH PARK, KIN023C                 KING               71526
# 4  ALKI BEACH PARK, KIN023A                 KING               71525
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0           29-Aug-22
# 1           29-Aug-22
# 2           29-Aug-22
# 3           22-Aug-22
# 4           22-Aug-22
#
# ...

# %%
WA_4["Result\nValue\n(Def.)"] = pd.to_numeric(WA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_4_Total = WA_4["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_4_Total))
# Out:
# Mean: 12

# %%
WA_4["Result\nValue\n(Def.)"] = pd.to_numeric(WA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_4_Aug= WA_4["Result\nValue\n(Def.)"][0:8].mean()



print("Mean:", round(calculation_WA_4_Aug))
# Out:
# Mean: 14

# %%
WA_4["Result\nValue\n(Def.)"] = pd.to_numeric(WA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_4_Jul= WA_4["Result\nValue\n(Def.)"][9:17].mean()



print("Mean:", round(calculation_WA_4_Jul))
# Out:
# Mean: 13

# %%
WA_4["Result\nValue\n(Def.)"] = pd.to_numeric(WA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_4_Jun= WA_4["Result\nValue\n(Def.)"][18:26].mean()



print("Mean:", round(calculation_WA_4_Jun))
# Out:
# Mean: 11

# %%
WA_4["Result\nValue\n(Def.)"] = pd.to_numeric(WA_4["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_4_May= WA_4["Result\nValue\n(Def.)"][27:29].mean()



print("Mean:", round(calculation_WA_4_May))
# Out:
# Mean: 10

# %%
WA_5= pd.read_csv("../work/WA_5.csv")

WA_5['Start\nTime\n(Def.)'] = WA_5['Start\nTime\n(Def.)'].str.replace('-','')
WA_5['Zone\nCode\n(Def.)'] = WA_5['Zone\nCode\n(Def.)'].str.replace('-','')

WA_5['Date']= pd.to_datetime(WA_5['Start\nDate\n(Def.)'],errors='raise')
WA_5.head()
# Out:
#   Beach ID\n(Def.) Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA878755        Sooes Beach             CLA004A
# 1         WA878755        Sooes Beach             CLA004B
# 2         WA878755        Sooes Beach             CLA004C
# 3         WA878755        Sooes Beach             CLA004A
# 4         WA878755        Sooes Beach             CLA004B
#
#    Station Name\n(Def.) County\nName\n(Def.)  Identifier\n(Def.)  \
# 0  SOOES BEACH, CLA004A              CLALLAM               72015
# 1  SOOES BEACH, CLA004B              CLALLAM               72014
# 2  SOOES BEACH, CLA004C              CLALLAM               72013
# 3  SOOES BEACH, CLA004A              CLALLAM               71999
# 4  SOOES BEACH, CLA004B              CLALLAM               71998
#
#   Start\nDate\n(Def.) Start\nTime\n(Def.) Zone\nCode\n(Def.)  \
# 0      19-December-22
# 1      19-December-22
# 2      19-December-22
# 3      14-December-22
# 4      14-December-22
#
# ...

# %%
WA_5["Result\nValue\n(Def.)"] = pd.to_numeric(WA_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_5_Total = WA_5["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_5_Total))
# Out:
# Mean: 14

# %%
WA_5["Result\nValue\n(Def.)"] = pd.to_numeric(WA_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_5_Dec= WA_5["Result\nValue\n(Def.)"][0:8].mean()



print("Mean:", round(calculation_WA_5_Dec))
# Out:
# Mean: 20

# %%
WA_5["Result\nValue\n(Def.)"] = pd.to_numeric(WA_5["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_5_Nov= WA_5["Result\nValue\n(Def.)"][9:18].mean()



print("Mean:", round(calculation_WA_5_Nov))
# Out:
# Mean: 10

# %%
WA_6= pd.read_csv("../work/WA_6.csv")

WA_6['Start\nTime\n(Def.)'] = WA_6['Start\nTime\n(Def.)'].str.replace('-','')
WA_6['Zone\nCode\n(Def.)'] = WA_6['Zone\nCode\n(Def.)'].str.replace('-','')

WA_6['Date']= pd.to_datetime(WA_6['Start\nDate\n(Def.)'],errors='raise')

WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6= WA_6["Result\nValue\n(Def.)"].mean()

WA_6.head()
# Out:
#   Beach ID\n(Def.)                   Beach Name\n(Def.) Station\nID\n(Def.)  \
# 0         WA673259  Westhaven State Park, Half Moon Bay             GRA018B
# 1         WA673259  Westhaven State Park, Half Moon Bay             GRA018A
# 2         WA673259  Westhaven State Park, Half Moon Bay             GRA018C
# 3         WA673259  Westhaven State Park, Half Moon Bay             GRA018B
# 4         WA673259  Westhaven State Park, Half Moon Bay             GRA018A
#
#                            Station Name\n(Def.) County\nName\n(Def.)  \
# 0  WESTHAVEN STATE PARK, HALF MOON BAY, GRA018B         GRAYS HARBOR
# 1  WESTHAVEN STATE PARK, HALF MOON BAY, GRA018A         GRAYS HARBOR
# 2  WESTHAVEN STATE PARK, HALF MOON BAY, GRA018C         GRAYS HARBOR
# 3  WESTHAVEN STATE PARK, HALF MOON BAY, GRA018B         GRAYS HARBOR
# 4  WESTHAVEN STATE PARK, HALF MOON BAY, GRA018A         GRAYS HARBOR
#
#    Identifier\n(Def.) Start\nDate\n(Def.) Start\nTime\n(Def.)  \
# ...

# %%
WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6_Total = WA_6["Result\nValue\n(Def.)"].mean()


print("Mean:", round(calculation_WA_6_Total))
# Out:
# Mean: 12

# %%
WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6_Aug= WA_6["Result\nValue\n(Def.)"][0:15].mean()



print("Mean:", round(calculation_WA_6_Aug))
# Out:
# Mean: 13

# %%
WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6_Jul= WA_6["Result\nValue\n(Def.)"][16:29].mean()



print("Mean:", round(calculation_WA_6_Jul))
# Out:
# Mean: 11

# %%
WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6_Jun= WA_6["Result\nValue\n(Def.)"][30:42].mean()



print("Mean:", round(calculation_WA_6_Jun))
# Out:
# Mean: 12

# %%
WA_6["Result\nValue\n(Def.)"] = pd.to_numeric(WA_6["Result\nValue\n(Def.)"], errors='coerce')

calculation_WA_6_May= WA_6["Result\nValue\n(Def.)"][43:49].mean()



print("Mean:", round(calculation_WA_6_May))
# Out:
# Mean: 10

# %%
#average of the results; graph it by the temperature - 5 beaches, or the same vincinty and see if its truly the temperature that effects the bacteria.

# %%
#sorted_high = df.sort_values(by = "Result\nValue\n(Def.)")
#sorted_high

# %%
# take away the beach name column - add in the result value in its place when i merge
# I can do a bar graph, or chart...

# %%
Avg_Results = pd.read_csv("../work/Avg. Results.csv")
Avg_Results.head()
# Out:
#       Beach Name Avg. Results January Avg. Results February  \
# 0   Crissy Field                    -                     -
# 1  Newport Beach                    -                     -
# 2  San Diego Bay                    -                     -
# 3  La Jolla Cove                    -                     -
# 4   Laguna Beach                    -                     -
#
#   Avg. Results March Avg. Results April Avg. Results May Avg. Results June  \
# 0                  -                  -                -                 -
# 1                  -                  -                -                 -
# 2                  -                  -                -                 -
# 3                  -                134             1323              1872
# 4                  -                  -                -                 -
#
#   Avg. Results July Avg. Results August Avg. Results September  \
# 0                 -                   -                      -
# ...

# %%
Avg_Results['Avg. Results December'] = Avg_Results['Avg. Results December'].str.replace('2331','-')
Avg_Results
# Out:
#                              Beach Name Avg. Results January  \
# 0                          Crissy Field                    -
# 1                         Newport Beach                    -
# 2                         San Diego Bay                    -
# 3                         La Jolla Cove                    -
# 4                          Laguna Beach                    -
# 5      Julia Pfeiffer Burns State Beach                 3445
# 6                Thornhill Broome Beach                    -
# 7                      BASTENDORF BEACH                    -
# 8                          HECETA BEACH                    -
# 9                          CANNON BEACH                    -
# 10                        SEASIDE BEACH                    -
# 11                           MILL BEACH                    -
# 12            AGATE BEACH STATE WAYSIDE                    -
# 13         NESKOWIN BEACH STATE WAYSIDE                    -
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def dash_to_zero(s):
    if '-' in s:
        return int(0)
    else:
        return int(s)

# %%
X = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
X_axis = np.arange(1, len(X)+1)

CA1 = Avg_Results.loc[Avg_Results["Beach Name"] == "Crissy Field" ]
CA1 = CA1.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA1 = [dash_to_zero(s) for s in CA1]
AvgCA1

x = X
y= AvgCA1

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Crissy Field, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
CA2 = Avg_Results.loc[Avg_Results["Beach Name"] == "Newport Beach" ]
CA2 = CA2.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA2 = [dash_to_zero(s) for s in CA2]


x = X
y= AvgCA2

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Newport Beach, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
CA3 = Avg_Results.loc[Avg_Results["Beach Name"] == "San Diego Bay" ]
CA3 = CA3.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA3 = [dash_to_zero(s) for s in CA3]


x = X
y= AvgCA3

plt.xticks(X_axis, X, rotation=90)
plt.scatter(x, y)
plt.xlabel('San Diego Bay, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
CA4 = Avg_Results.loc[Avg_Results["Beach Name"] == "La Jolla Cove" ]
CA4 = CA4.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA4 = [dash_to_zero(s) for s in CA4]


x = X
y= AvgCA4

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('La Jolla Cove, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.savefig("Avg_Results_Jolla.png")
plt.show()

# %%
CA5 = Avg_Results.loc[Avg_Results["Beach Name"] == "Laguna Beach" ]
CA5 = CA5.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA5 = [dash_to_zero(s) for s in CA5]


x = X
y= AvgCA5

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Laguna Beach, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
CA6 = Avg_Results.loc[Avg_Results["Beach Name"] == "Julia Pfeiffer Burns State Beach" ]
CA6 = CA6.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA6 = [dash_to_zero(s) for s in CA6]


x = X
y= AvgCA6

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Julia Pfeiffer Burns State Beach, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
CA7 = Avg_Results.loc[Avg_Results["Beach Name"] == "Thornhill Broome Beach" ]
CA7 = CA7.drop(columns='Beach Name').T.values.flatten().tolist()
AvgCA7 = [dash_to_zero(s) for s in CA7]


x = X
y= AvgCA7

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Thornhill Broome Beach, CA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR1 = Avg_Results.loc[Avg_Results["Beach Name"] == "BASTENDORF BEACH" ]
OR1 = OR1.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR1 = [dash_to_zero(s) for s in OR1]


x = X
y= AvgOR1

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Bastendorf Beach, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR2 = Avg_Results.loc[Avg_Results["Beach Name"] == "HECETA BEACH" ]
OR2 = OR2.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR2 = [dash_to_zero(s) for s in OR2]


x = X
y= AvgOR2

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Heceta Beach, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR3 = Avg_Results.loc[Avg_Results["Beach Name"] == "CANNON BEACH" ]
OR3 = OR3.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR3 = [dash_to_zero(s) for s in OR3]


x = X
y= AvgOR3

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Cannon Beach, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR4 = Avg_Results.loc[Avg_Results["Beach Name"] == "SEASIDE BEACH" ]
OR4 = OR4.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR4 = [dash_to_zero(s) for s in OR4]


x = X
y= AvgOR4

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Seaside Beach, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR5 = Avg_Results.loc[Avg_Results["Beach Name"] == "MILL BEACH" ]
OR5 = OR5.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR5 = [dash_to_zero(s) for s in OR5]


x = X
y= AvgOR5

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Mill Beach, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR6 = Avg_Results.loc[Avg_Results["Beach Name"] == "AGATE BEACH STATE WAYSIDE" ]
OR6 = OR6.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR6 = [dash_to_zero(s) for s in OR6]


x = X
y= AvgOR6

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Agate Beach Sate Wayside, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
OR7 = Avg_Results.loc[Avg_Results["Beach Name"] == "NESKOWIN BEACH STATE WAYSIDE" ]
OR7 = OR7.drop(columns='Beach Name').T.values.flatten().tolist()
AvgOR7 = [dash_to_zero(s) for s in OR7]


x = X
y= AvgOR7

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Neskowin Beach State Wayside, OR')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
WA1 = Avg_Results.loc[Avg_Results["Beach Name"] == "Jetty Island" ]
WA1 = WA1.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA1 = [dash_to_zero(s) for s in WA1]


x = X
y= AvgWA1

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Jetty Island, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
WA2 = Avg_Results.loc[Avg_Results["Beach Name"] == "Port of Bellingham Marine Park" ]
WA2 = WA2.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA2 = [dash_to_zero(s) for s in WA2]


x = X
y= AvgWA2

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Port of Bellingham Marine Park, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
WA3 = Avg_Results.loc[Avg_Results["Beach Name"] == "Arness County Park" ]
WA3 = WA3.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA3 = [dash_to_zero(s) for s in WA3]


x = X
y= AvgWA3

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Arness County Park, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
WA4 = Avg_Results.loc[Avg_Results["Beach Name"] == "Alki Beach Park" ]
WA4 = WA4.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA4 = [dash_to_zero(s) for s in WA4]


x = X
y= AvgWA4

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Alki Beach Park, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()
plt.savefig("figure.png")

# %%
WA5 = Avg_Results.loc[Avg_Results["Beach Name"] == "Sooes Beach" ]
WA5 = WA5.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA5 = [dash_to_zero(s) for s in WA5]


x = X
y= AvgWA5

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Sooes Beach, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
WA6 = Avg_Results.loc[Avg_Results["Beach Name"] == "Westhaven State Park, Half Moon Bay" ]
WA6 = WA6.drop(columns='Beach Name').T.values.flatten().tolist()
AvgWA6 = [dash_to_zero(s) for s in WA6]


x = X
y= AvgWA6

plt.xticks(X_axis,X, rotation=90)
plt.scatter(X_axis, y)
plt.xlabel('Westhaven State Park, Half Moon Bay, WA')
plt.ylabel('Bacteria')
plt.title('Scatter Plot')
plt.show()

# %%
temp= pd.read_csv("../work/Water_Temp.csv")
temp.head()
# Out:
#       Beach Name  January  February  March  April   May  June  July  August  \
# 0   Crissy Field     53.3      53.1   53.1   52.2  52.3  53.4  55.5    57.3
# 1  Newport Beach     58.3      58.4   58.2   58.0  60.9  63.1  63.4    63.8
# 2  San Diego Bay     59.1      60.3   62.4   64.1  66.9  69.5  71.7    72.1
# 3  La Jolla Cove     58.9      58.9   59.7   60.9  64.1  66.3  67.8    68.3
# 4   Laguna Beach     58.4      58.2   58.2   58.1  60.9  63.2  63.4    63.9
#
#    September  October  November  December
# 0       57.9     56.9      55.4      54.0
# 1       64.6     64.1      62.0      59.5
# 2       71.6     69.3      65.3      60.6
# 3       67.5     65.8      62.9      60.1
# 4       64.6     64.1      62.0      59.6

# %%
import geopandas

# %config InlineBackend.figure_format ='retina'

# %%
#merged.plot.scatter(x=

# %%
def dash_to_zero(s):
    if '-' in s:
        return int(0)
    else:
        return int(s)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
X = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


b_1 = Avg_Results.loc[Avg_Results["Beach Name"] == "Thornhill Broome Beach" ]
b_1 = b_1.drop(columns='Beach Name').T.values.flatten().tolist()
Result1 = [dash_to_zero(s) for s in b_1]

# b = temp.loc[temp["Beach Name"] == "Crissy Field" ]
# b = b.drop(columns='Beach Name').T.values.flatten().tolist()
# data2 = [dash_to_zero(s) for s in b]

# data1 =  Avg_Results.loc[temp["Beach Name"] == "Crissy Field" ].values.flatten().tolist()
Temp1 = temp.loc[temp["Beach Name"] == "Thornhill Broome Beach" ]
Temp1= Temp1.drop(columns="Beach Name").values.flatten().tolist()
Temp1
# Out:
# [58.3, 58.5, 59.2, 59.6, 62.7, 65.9, 67.8, 68.3, 67.8, 65.5, 62.1, 59.1]

# %%
Result1
# Out:
# [0, 0, 0, 0, 0, 10, 10, 11, 10, 11, 0, 0]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Thornhill Broome Beach, CA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result1, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp1, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.savefig('Double_Thornhill.jpg')
plt.show()

# %%
#save image

# %%
b_2 = Avg_Results.loc[Avg_Results["Beach Name"] == "La Jolla Cove" ]
b_2 = b_2.drop(columns='Beach Name').T.values.flatten().tolist()
Result2 = [dash_to_zero(s) for s in b_2]


Temp2 = temp.loc[temp["Beach Name"] == "La Jolla Cove" ]
Temp2= Temp2.drop(columns="Beach Name").values.flatten().tolist()
Result2
# Out:
# [0, 0, 0, 134, 1323, 1872, 1808, 2419, 1676, 1446, 1216, 0]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('La Jolla Cove, CA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result2, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp2, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.savefig('Double_Jolla.jpg')
plt.show()

# %%
b_3 = Avg_Results.loc[Avg_Results["Beach Name"] == "CANNON BEACH" ]
b_3 = b_3.drop(columns='Beach Name').T.values.flatten().tolist()
Result3 = [dash_to_zero(s) for s in b_3]


Temp3 = temp.loc[temp["Beach Name"] == "CANNON BEACH" ]
Temp3= Temp3.drop(columns="Beach Name").values.flatten().tolist()
Temp3
# Out:
# [49.0, 48.9, 49.7, 51.4, 53.7, 56.1, 56.0, 55.1, 55.5, 54.4, 52.0, 49.7]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Cannon Beach, OR')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result3, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp3, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.savefig('Double_Cannon.jpg')
plt.show()

# %%
b_4 = Avg_Results.loc[Avg_Results["Beach Name"] == "BASTENDORF BEACH" ]
b_4 = b_4.drop(columns='Beach Name').T.values.flatten().tolist()
Result4 = [dash_to_zero(s) for s in b_4]


Temp4 = temp.loc[temp["Beach Name"] == "BASTENDORF BEACH" ]
Temp4= Temp4.drop(columns="Beach Name").values.flatten().tolist()
Temp4
# Out:
# [49.5, 49.5, 50.4, 51.0, 52.5, 53.6, 53.2, 53.5, 53.9, 53.4, 52.3, 50.4]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Bastendorf, OR')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result4, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp4, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature", fontsize=10)
plt.savefig('Double_Bastendorf.jpg')
plt.show()

# %%
b_5 = Avg_Results.loc[Avg_Results["Beach Name"] == "MILL BEACH" ]
b_5 = b_5.drop(columns='Beach Name').T.values.flatten().tolist()
Result5 = [dash_to_zero(s) for s in b_5]


Temp5 = temp.loc[temp["Beach Name"] == "MILL BEACH" ]
Temp5= Temp5.drop(columns="Beach Name").values.flatten().tolist()
Temp5
# Out:
# [49.5, 48.4, 48.0, 48.5, 50.9, 54.4, 58.8, 62.5, 63.0, 60.1, 55.4, 51.8]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Mill Beach, OR')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result5, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp5, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.show()

# %%
b_6 = Avg_Results.loc[Avg_Results["Beach Name"] == "Jetty Island" ]
b_6 = b_6.drop(columns='Beach Name').T.values.flatten().tolist()
Result6 = [dash_to_zero(s) for s in b_6]


Temp6 = temp.loc[temp["Beach Name"] == "Jetty Island" ]
Temp6= Temp6.drop(columns="Beach Name").values.flatten().tolist()
Temp6
# Out:
# [46.5, 46.3, 46.8, 48.1, 49.7, 51.1, 52.3, 52.9, 52.2, 51.0, 49.3, 47.5]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Jetty Island, WA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result6, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp6, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.savefig('Double_Jetty.jpg')
plt.show()

# %%
b_7 = Avg_Results.loc[Avg_Results["Beach Name"] == "Port of Bellingham Marine Park" ]
b_7 = b_7.drop(columns='Beach Name').T.values.flatten().tolist()
Result7 = [dash_to_zero(s) for s in b_7]


Temp7 = temp.loc[temp["Beach Name"] == "Port of Bellingham Marine Park" ]
Temp7= Temp7.drop(columns="Beach Name").values.flatten().tolist()
Temp7
# Out:
# [45.0, 44.7, 45.0, 47.1, 48.7, 51.6, 52.5, 53.1, 52.5, 50.7, 49.1, 47.4]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Port of Bellingham Marine Park, WA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result7, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp7, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.show()

# %%
b_8 = Avg_Results.loc[Avg_Results["Beach Name"] == "San Diego Bay" ]
b_8 = b_8.drop(columns='Beach Name').T.values.flatten().tolist()
Result8 = [dash_to_zero(s) for s in b_8]


Temp8 = temp.loc[temp["Beach Name"] == "San Diego Bay" ]
Temp8= Temp8.drop(columns="Beach Name").values.flatten().tolist()
Temp8
# Out:
# [59.1, 60.3, 62.4, 64.1, 66.9, 69.5, 71.7, 72.1, 71.6, 69.3, 65.3, 60.6]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('San Diego Bay, CA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result8, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp8, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature")
plt.show()

# %%
b_9 = Avg_Results.loc[Avg_Results["Beach Name"] == "Arness County Park" ]
b_9 = b_9.drop(columns='Beach Name').T.values.flatten().tolist()
Result9 = [dash_to_zero(s) for s in b_9]


Temp9 = temp.loc[temp["Beach Name"] == "Arness County Park" ]
Temp9= Temp9.drop(columns="Beach Name").values.flatten().tolist()
Temp9
# Out:
# [46.3, 46.6, 46.8, 48.1, 49.7, 51.1, 51.3, 52.9, 52.2, 51.2, 49.7, 47.5]

# %%
fig, ax1 = plt.subplots()
X_axis = np.arange(1, len(X)+1)

color = 'tab:red'
ax1.set_xlabel('Arness County Park, WA')
ax1.set_ylabel('Average Bacteria', color=color)
ax1.plot(X_axis, Result9, color=color)
plt.xticks(X_axis, X, rotation=90)
# ax1.tick_params(axis='X', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Average Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(X_axis, Temp9, color=color)
# ax2.tick_params(axis='X', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Correlation Between Bacteria and Temperature", fontsize=10)
plt.show()

# %%
#Did this to see the parameters of bacteria 
CA_4_Ecoli = CA_4[CA_4['Characteristic\nName\n(Def.)'] == 'Escherichia coli']
CA_4_Ecoli

x = CA_4_Ecoli['Date']
y = CA_4_Ecoli['Result\nValue\n(Def.)']
plt.xlabel('La Jolla Cove, WA')
plt.xticks(rotation=90)
plt.scatter(x,y)

# %%
Averages_All= pd.read_csv("../work/Final - Averages All.csv")
Averages_All
# Out:
#     Averages_All
# 0            707
# 1             98
# 2            302
# 3           2669
# 4             27
# 5            471
# 6             11
# 7             92
# 8             49
# 9             74
# 10            23
# 11            53
# 12            36
# 13            21
# 14            12
# 15            70
# 16            14
# 17            12
# 18            14
# 19            12

# %%
import geopandas as gpd

# %config InlineBackend.figure_format ='retina' 
WestCoast = gpd.read_file("../work/custom.geo (1).json")
WestCoast.plot()
# Out:
# <AxesSubplot:>

# %%
# create a list of coordinates as tuples
coords = [(37.8066, -122.4489), (33.6287, -117.9578), (32.7078, -117.237), (32.8502, -117.2723) , (33.5568, -117.8196), (36.2498, -121.8366), (34.0835, -119.0379), (43.352022, -124.344706),(44.04852, -124.13125), (45.9176, -123.9758), (46.00656, -123.929641), (42.0489, -124.2946), (44.6738, -124.0646), (45.15916, -123.9702), (48.0078, -122.23133), (48.721, -122.51565), (47.7941, -122.50553),(47.5779, -122.41591), (48.324, -124.658), (46.9043, -124.1223) ]

# convert the list to a pandas dataframe
df = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

df['Averages_All'] = Averages_All

colors = []
for index, row in df.iterrows():
    if row["Averages_All"] <= 10:
        colors.append("green")
    elif row["Averages_All"] <= 50:
        colors.append("orange")
    else:
        colors.append("red")

df["Color"] = colors


#set the parameters of plot
desired_extent = (-130, -115, 30, 50)


ax = WestCoast.plot()
ax.set_xlim(desired_extent[0], desired_extent[1])
ax.set_ylim(desired_extent[2], desired_extent[3])


for index, row in df.iterrows():
    ax.scatter(row["Longitude"], row["Latitude"], color=row["Color"])

# label axis
ax.set_xticks(range(-130, -115, 5))
#ax.set_xticklabels(['90°W','85°W','80°W','75°W','70°W','65°W', '60°W'])
ax.set_yticks(range(30, 55, 5))
# ax.set_yticklabels(['25°N', '30°N', '35°N', '40°N', '45°N', '50°N'])
ax.set_xlabel('Longitude', fontsize=12)
ax.set_ylabel('Latitude', fontsize=12)

ax.grid()

plt.title("West Coast")
# show the
plt.savefig('West_Coast_Map.png')
plt.show()
